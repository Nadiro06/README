# %%
# Este notebook incluiría comparaciones entre métricas de desempeño,
# tales como precisión, recall, F1 y AUC entre los dos modelos.
# También incluiría una discusión sobre cuál modelo es más confiable y por qué.

print("Comparar las salidas de los modelos desde los notebooks 03 y 04.")
print("Analizar matrices de confusión, curvas ROC, y métricas de clasificación.")
